# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/dataset.csv')

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
dicionario = pd.DataFrame([
    {
        'variavel':'age',
        'descrição':'idade do indivíduo observado',
        'tipo':'quantitativa',
        'subtipo':'discreta'
    },
    {
        'variavel':'sex',
        'descrição':'sexo do indivíduo observado, 1 = masculino, 0 = feminino',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'chest pain type',
        'descrição': '''tipo de dor no peito, 
                        1 = angina típica
                        2 = angina atípica
                        3 = dor não anginosa
                        4 = assintomática''',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'resting bp s',
        'descrição':'pressão arterial em repouso, medido em mm Hg (milímetros de mercúrio)',
        'tipo':'quantitativa',
        'subtipo':'discreta'
    },
    {
        'variavel':'cholesterol',
        'descrição':'nível de colesterol no sangue, medido em mg/dl (miligramas por decilitro)',
        'tipo':'quantitativa',
        'subtipo':'discreta'
    },
    {
        'variavel':'fasting blood sugar',
        'descrição':'quantidade de açúcar no sangue, 1 = se for maior que 120mg/dl, 0 = caso contrario',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'resting ecg',
        'descrição':'''resultado do eletrocardiograma em repouso
                       0 = Normal
                       1 = apresentando anormalidade de onda ST-T (inversões da onda T e/ou elevação ou 
                           depressão do segmento ST de > 0,05 mV) mV = milivolt.
                       2 = mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes.''',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'max heart rate',
        'descrição':'frequencia cardíaca máxima alcançada',
        'tipo':'quantitativa',
        'subtipo':'discreta'
    },
    {
        'variavel':'exercise angina',
        'descrição':'angina induzida por exercício, 1 = sim, 0 = não',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'oldpeak',
        'descrição':'medida da elevação/depressão do segmento ST',
        'tipo':'quantitativa',
        'subtipo':'continua'
    },
    {
        'variavel':'ST slope',
        'descrição':'''inclinação do segmento ST no pico do exercício
                       1 = ascendente
                       2 = plana
                       3 = descendente''',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    },
    {
        'variavel':'target',
        'descrição':'classe a qual o individuo pertence, 1 = doença cardíaca, 0 = normal',
        'tipo':'qualitativa',
        'subtipo':'nominal'
    }
])

# %%
dicionario = dicionario.set_index("variavel")

# %%
dicionario
# Out:
#                                                              descrição  \
# variavel
# age                                       idade do indivíduo observado
# sex                  sexo do indivíduo observado, 1 = masculino, 0 ...
# chest pain type      tipo de dor no peito, \n                      ...
# resting bp s         pressão arterial em repouso, medido em mm Hg (...
# cholesterol          nível de colesterol no sangue, medido em mg/dl...
# fasting blood sugar  quantidade de açúcar no sangue, 1 = se for mai...
# resting ecg          resultado do eletrocardiograma em repouso\n   ...
# max heart rate                    frequencia cardíaca máxima alcançada
# exercise angina        angina induzida por exercício, 1 = sim, 0 = não
# oldpeak                    medida da elevação/depressão do segmento ST
# ST slope             inclinação do segmento ST no pico do exercício...
# target               classe a qual o individuo pertence, 1 = doença...
#
# ...

# %%
dicionario.to_csv('../data/external/dicionario.csv')
