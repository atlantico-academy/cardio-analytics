# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/dataset.csv')

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
dicionario = pd.DataFrame([
    {
    'variavel':'age',
    'descrição':'idade do indivíduo observado',
    'tipo':'quantitativa',
    'subtipo':'discreta'
    },
    {
    'variavel':'sex',
    'descrição':'sexo do indivíduo observado, 1 = masculino, 0 = feminino',
    'tipo':'qualitativa',
    'subtipo':'nominal'
    },
    {
    'variavel':'chest pain type',
    'descrição': '''tipo de dor no peito, 
                    1 = angina típica
                    2 = angina atípica
                    3 = dor não anginosa
                    4 = assintomática''',
    'tipo':'qualitativa',
    'subtipo':'nominal'
    },
    {
    'variavel':'resting bp s',
    'descrição':'pressão arterial em repouso, medido em mm Hg (milímetros de mercúrio)',
    'tipo':'quantitativa',
    'subtipo':'discreta'
    },
    {
    'variavel':'cholesterol',
    'descrição':'nível de colesterol no sangue, medido em mg/dl (miligramas por decilitro)',
    'tipo':'quantitativa',
    'subtipo':'discreta'
    },
    {
    'variavel':'fasting blood sugar',
    'descrição':'quantidade de açúcar no sangue, medido em mg/dl, 1 = se for maior que 120mg/dl, 0 = caso contrario',
    'tipo':'quantitativa',
    'subtipo':'discreta/binaria'
    },
    {
    'variavel':'resting ecg',
    'descrição':'''resultado do eletrocardiograma em repouso
                   0 = Normal
                   1 = apresentando anormalidade de onda ST-T (inversões da onda T e/ou elevação ou 
                                                               depressão do segmento ST de > 0,05 mV) mV = milivolt
                   2 = mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes.''',
    'tipo':'qualitativa',
    'subtipo':'nominal'
    },
    {
    'variavel':'max heart rate',
    'descrição':'frequencia cardíaca máxima alcançada',
    'tipo':'quantitativa',
    'subtipo':'discreta'
    },
    {
    'variavel':'exercise angina',
    'descrição':'angina induzida por exercício, 1 = sim, 0 = não',
    'tipo':'quantitativa',
    'subtipo':'discreta/binaria'
    },
    {
    'variavel':'oldpeak',
    'descrição':'medida da elevação/depressão do segmento ST',
    'tipo':'quantitativa',
    'subtipo':'continua'
    },
    {
    'variavel':'ST slope',
    'descrição':'''inclinação do segmento ST no pico do exercício
                   1 = ascendente
                   2 = plana
                   3 = descendente''',
    'tipo':'quantitativa',
    'subtipo':'discreta'
    },
    {
    'variavel':'target',
    'descrição':'classe a qual o individuo pertence, 1 = doença cardíaca, 0 = normal',
    'tipo':'quantitativa',
    'subtipo':'discreta/binaria'
    }
])

# %%
dicionario
# Out:
#                variavel                                          descrição  \
# 0                   age                       idade do indivíduo observado
# 1                   sex  sexo do indivíduo observado, 1 = masculino, 0 ...
# 2       chest pain type  tipo de dor no peito, \n                    1 ...
# 3          resting bp s  pressão arterial em repouso, medido em mm Hg (...
# 4           cholesterol  nível de colesterol no sangue, medido em mg/dl...
# 5   fasting blood sugar  quantidade de açúcar no sangue, medido em mg/d...
# 6           resting ecg  resultado do eletrocardiograma em repouso\n   ...
# 7        max heart rate               frequencia cardíaca máxima alcançada
# 8       exercise angina    angina induzida por exercício, 1 = sim, 0 = não
# 9               oldpeak        medida da elevação/depressão do segmento ST
# 10             ST slope  inclinação do segmento ST no pico do exercício...
# 11               target  classe a qual o individuo pertence, 1 = doença...
#
#             tipo           subtipo
# 0   quantitativa          discreta
# 1    qualitativa           nominal
# 2    qualitativa           nominal
# 3   quantitativa          discreta
# 4   quantitativa          discreta
# 5   quantitativa  discreta/binaria
# 6    qualitativa           nominal
# 7   quantitativa          discreta
# 8   quantitativa  discreta/binaria
# 9   quantitativa          continua
# 10  quantitativa          discreta
# 11  quantitativa  discreta/binaria

# %%
dicionario.to_csv('../references/dicionario.csv')
